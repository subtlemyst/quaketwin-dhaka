# %% [markdown]
# # Phase 0 — Data Inventory
#
# Catalog datasets for the thesis methodology chapter (Table 3.1).

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from quaketwin.schema.inventory import inventory_summary
from quaketwin.geo.dhaka import study_area_summary

print("Study area:", study_area_summary())
summary = inventory_summary()
print(f"Total sources: {summary['total_sources']}")
print("By layer:", summary["by_layer"])
